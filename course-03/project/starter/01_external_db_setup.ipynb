# %%
from datetime import datetime, timedelta
import json
import uuid
import random 
from sqlalchemy import create_engine

from utils import reset_db, get_session, model_to_dict
from data.models import cultpass

# %% [markdown]
# # Udahub Accounts

# %% [markdown]
# ## Cultpass Database

# %% [markdown]
# **Init DB**

# %%
cultpass_db = "data/external/cultpass.db"

# %%
reset_db(cultpass_db)
# Out:
# ✅ Removed existing data/external/cultpass.db
# 2026-03-11 00:09:23,995 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-03-11 00:09:23,996 INFO sqlalchemy.engine.Engine COMMIT
# ✅ Recreated data/external/cultpass.db with fresh schema

# %%
engine = create_engine(f"sqlite:///{cultpass_db}", echo=False)
cultpass.Base.metadata.create_all(engine)

# %% [markdown]
# **Experiences**

# %%
experience_data = []

with open('data/external/cultpass_experiences.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        experience_data.append(json.loads(line))

# %%
experience_data
# Out:
# [{'title': 'Carnival History Tour in Olinda',
#   'description': "Discover the origins and vibrant traditions of Pernambuco's Carnival.",
#   'location': 'Pernambuco, Brazil'},
#  {'title': 'Sunset Paddleboarding',
#   'description': 'Glide across calm waters at golden hour with all gear included.',
#   'location': 'Santa Catarina, Brazil'},
#  {'title': 'Pelourinho Colonial Walk',
#   'description': 'Wander through colorful streets and learn about Afro-Brazilian history.',
#   'location': 'Bahia, Brazil'},
#  {'title': 'Samba Night at Lapa',
#   'description': 'Dance the night away at a traditional samba club in the Lapa arches.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Christ the Redeemer Experience',
#   'description': 'Take a guided trip to one of the New Seven Wonders of the World with historical context.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Modern Art at MASP',
#   'description': 'Enjoy a guided visit to the São Paulo Museum of Art with insights into its top collections.',
#   'location': 'São Paulo, Brazil'},
#  {'title': 'Ibirapuera Park Bike Ride',
#   'description': "Cycle through the city's most iconic park with stops for photos and history.",
#   'location': 'São Paulo, Brazil'},
#  {'title': 'Capoeira Workshop in Salvador',
#   'description': 'Learn the ancient Afro-Brazilian martial art with an experienced instructor.',
#   'location': 'Bahia, Brazil'},
#  {'title': 'Ipanema Beach Sunset Yoga',
#   'description': 'Practice yoga on the famous beach as the sun sets over the Atlantic Ocean.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Street Art Tour in Vila Madalena',
#   'description': 'Explore vibrant murals and street art with a local artist guide.',
#   'location': 'São Paulo, Brazil'},
#  {'title': 'Forró Dance Classes',
#   'description': 'Master the traditional northeastern Brazilian dance in an authentic setting.',
#   'location': 'Pernambuco, Brazil'},
#  {'title': 'Bahia Culinary Experience',
#   'description': 'Cook traditional Bahian dishes with a local chef and taste the flavors of the region.',
#   'location': 'Bahia, Brazil'},
#  {'title': 'Sugarloaf Mountain Hike',
#   'description': "Trek to the top of Rio's iconic mountain with panoramic city views.",
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Indigenous Culture Workshop',
#   'description': 'Learn about Brazilian indigenous traditions, crafts, and history from community members.',
#   'location': 'Amazonas, Brazil'},
#  {'title': 'Botafogo Beach Volleyball',
#   'description': "Play beach volleyball with local professionals in Rio's historic neighborhood.",
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Copacabana Music Night',
#   'description': 'Experience live Brazilian music performances at traditional venues on the beach.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Iguazu Falls Eco-Tour',
#   'description': "Witness one of the world's most spectacular waterfalls with guided nature exploration.",
#   'location': 'Paraná, Brazil'},
#  {'title': 'Carnival Costume Workshop',
#   'description': 'Design and create your own carnival costume with professional artisans.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Bossa Nova Jazz Night',
#   'description': 'Enjoy smooth bossa nova jazz in an intimate Rio de Janeiro club.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Coffee Farm Tour',
#   'description': 'Visit a working coffee plantation in the highlands and learn the art of coffee production.',
#   'location': 'São Paulo, Brazil'},
#  {'title': 'Coral Reef Snorkeling',
#   'description': "Explore vibrant marine life in Brazil's protected coral reef systems.",
#   'location': 'Bahia, Brazil'},
#  {'title': 'Teatro Municipal Guided Tour',
#   'description': "Discover the architectural masterpiece of Rio's historic opera house.",
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Favela Cultural Tour',
#   'description': 'Experience authentic favela culture with local guides and community storytelling.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Macramé and Textile Workshop',
#   'description': 'Create traditional Brazilian textile art with local artisans in Salvador.',
#   'location': 'Bahia, Brazil'},
#  {'title': 'Beach Soccer Clinic',
#   'description': 'Learn Brazilian beach soccer techniques from experienced local players.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Afro-Brazilian Music Percussion Class',
#   'description': 'Master traditional drums and percussion instruments used in samba and traditional music.',
#   'location': 'Bahia, Brazil'},
#  {'title': 'Amazon Jungle Expedition',
#   'description': "Explore the rainforest's biodiversity with expert naturalist guides.",
#   'location': 'Amazonas, Brazil'},
#  {'title': 'Christ the Redeemer Sunrise Experience',
#   'description': 'Watch the sunrise from this iconic statue with meditation and reflection.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Copacabana Palace Heritage Tour',
#   'description': "Explore the legendary hotel's history and glamorous architecture.",
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Traditional Moqueca Cooking Class',
#   'description': 'Prepare the classic Brazilian seafood stew in a beachside kitchen.',
#   'location': 'Bahia, Brazil'},
#  {'title': 'Corcovado Train Ride',
#   'description': 'Take a scenic cogwheel train through the Atlantic Forest to Christ the Redeemer.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Brazilian Pottery Workshop',
#   'description': 'Learn ceramic techniques inspired by indigenous and colonial traditions.',
#   'location': 'Pernambuco, Brazil'},
#  {'title': 'Lapa Street Art Mural Tour',
#   'description': "Discover the history and techniques behind Rio's famous street murals.",
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Manaus Opera House Tour',
#   'description': 'Visit the legendary theatre in the heart of the Amazon.',
#   'location': 'Amazonas, Brazil'},
#  {'title': 'Tropical Fruit Market Experience',
#   'description': 'Explore exotic Brazilian fruits at a traditional market with tasting samples.',
#   'location': 'São Paulo, Brazil'},
#  {'title': 'Samba School Rehearsal Visit',
#   'description': 'Watch carnival samba school rehearsals and learn their choreography.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Pantanal Wildlife Safari',
#   'description': "Spot jaguars, capybaras, and exotic birds in the world's largest tropical wetland.",
#   'location': 'Mato Grosso, Brazil'},
#  {'title': "Bahian Women's Circle",
#   'description': 'Connect with local women and learn about their cultural traditions and stories.',
#   'location': 'Bahia, Brazil'},
#  {'title': 'Sugar Mill Historical Tour',
#   'description': "Visit a preserved colonial sugar mill and learn about Brazil's agricultural history.",
#   'location': 'Pernambuco, Brazil'},
#  {'title': 'Samba Costuming and Styling',
#   'description': 'Get dressed in full carnival attire with guidance from professional stylists.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Tropical Plant Botanical Walk',
#   'description': 'Explore rare Brazilian flora with a botanist in a nature reserve.',
#   'location': 'São Paulo, Brazil'},
#  {'title': 'Candombe Drums Workshop',
#   'description': "Learn the sacred rhythms of Candombe, Brazil's most spiritual music form.",
#   'location': 'Bahia, Brazil'},
#  {'title': 'Rio Food Tour',
#   'description': 'Taste street food and local specialties while exploring historic Rio neighborhoods.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Pampas Horseback Riding',
#   'description': 'Ride through the southern Brazilian grasslands like a traditional gaucho.',
#   'location': 'Rio Grande do Sul, Brazil'},
#  {'title': 'Sacred Waterfall Meditation',
#   'description': 'Experience spiritual healing at a sacred waterfall with local shamans.',
#   'location': 'Bahia, Brazil'},
#  {'title': 'Brazilian Martial Arts Festival',
#   'description': 'Participate in capoeira, jiu-jitsu, and other traditional combat arts.',
#   'location': 'São Paulo, Brazil'},
#  {'title': 'Tidal Wave Surfing Experience',
#   'description': 'Ride the famous tidal bore waves in the Amazon River with expert surfers.',
#   'location': 'Amazonas, Brazil'},
#  {'title': 'Candomblé Spiritual Ceremony',
#   'description': 'Witness authentic Candomblé religious ceremonies with community participation.',
#   'location': 'Bahia, Brazil'},
#  {'title': 'Brazilian Literature Salon',
#   'description': 'Discuss works by great Brazilian authors in an intimate literary setting.',
#   'location': 'Rio de Janeiro, Brazil'},
#  {'title': 'Sustainable Rainforest Project',
#   'description': 'Participate in conservation efforts and learn about Amazon preservation.',
#   'location': 'Amazonas, Brazil'}]

# %%
with get_session(engine) as session:
    experiences = []

    for idx, experience in enumerate(experience_data):
        exp = cultpass.Experience(
            experience_id=str(uuid.uuid4())[:6],
            title=experience["title"],
            description=experience["description"],
            location=experience["location"],
            when=datetime.now() + timedelta(days=idx+1),
            slots_available=random.randint(1,30),
            is_premium=(idx % 2 == 0)
        )
        experiences.append(exp)

    session.add_all(experiences)

# %% [markdown]
# **User**

# %%
cultpass_users = []

with open('data/external/cultpass_users.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        cultpass_users.append(json.loads(line))

# %%
cultpass_users
# Out:
# [{'id': 'a4ab87',
#   'name': 'Alice Kingsley',
#   'email': 'alice.kingsley@wonderland.com',
#   'is_blocked': True},
#  {'id': 'f556c0',
#   'name': 'Bob Stone',
#   'email': 'bob.stone@granite.com',
#   'is_blocked': False},
#  {'id': '88382b',
#   'name': 'Cathy Bloom',
#   'email': 'cathy.bloom@florals.org',
#   'is_blocked': False},
#  {'id': '888fb2',
#   'name': 'David Noir',
#   'email': 'david.noir@shadowmail.com',
#   'is_blocked': True},
#  {'id': 'f1f10d',
#   'name': 'Eva Green',
#   'email': 'eva.green@ecosoul.net',
#   'is_blocked': False},
#  {'id': 'e6376d',
#   'name': 'Frank Ocean',
#   'email': 'frank.ocean@seawaves.io',
#   'is_blocked': False},
#  {'id': 'g7h89i',
#   'name': 'Grace Harper',
#   'email': 'grace.harper@melodyarts.com',
#   'is_blocked': False},
#  {'id': 'h8i90j',
#   'name': 'Henry Mitchell',
#   'email': 'henry.mitchell@buildtech.io',
#   'is_blocked': True},
#  {'id': 'i9j01k',
#   'name': 'Iris Chen',
#   'email': 'iris.chen@technovate.net',
#   'is_blocked': False},
#  {'id': 'j0k12l',
#   'name': 'Jack Wilson',
#   'email': 'jack.wilson@sportsline.com',
#   'is_blocked': False},
#  {'id': 'k1l23m',
#   'name': 'Karen Santos',
#   'email': 'karen.santos@vibrantcultural.org',
#   'is_blocked': False},
#  {'id': 'l2m34n',
#   'name': 'Leo Martinez',
#   'email': 'leo.martinez@latinarts.io',
#   'is_blocked': True},
#  {'id': 'm3n45o',
#   'name': 'Maya Patel',
#   'email': 'maya.patel@eastbound.net',
#   'is_blocked': False},
#  {'id': 'n4o56p',
#   'name': 'Nathan Brooks',
#   'email': 'nathan.brooks@riverdesign.com',
#   'is_blocked': False},
#  {'id': 'o5p67q',
#   'name': 'Olivia Schmidt',
#   'email': 'olivia.schmidt@europeanculture.de',
#   'is_blocked': False},
#  {'id': 'p6q78r',
#   'name': 'Patrick Murphy',
#   'email': 'patrick.murphy@irishheritage.ie',
#   'is_blocked': True},
#  {'id': 'q7r89s',
#   'name': 'Quinn Davis',
#   'email': 'quinn.davis@youngcreatives.io',
#   'is_blocked': False},
#  {'id': 'r8s90t',
#   'name': 'Rachel Adams',
#   'email': 'rachel.adams@modernart.net',
#   'is_blocked': False},
#  {'id': 's9t01u',
#   'name': 'Samuel Kim',
#   'email': 'samuel.kim@asianfusion.org',
#   'is_blocked': False},
#  {'id': 't0u12v',
#   'name': 'Tara Johnson',
#   'email': 'tara.johnson@danceworld.io',
#   'is_blocked': True},
#  {'id': 'u1v23w',
#   'name': 'Uma Gupta',
#   'email': 'uma.gupta@classicalmusic.net',
#   'is_blocked': False},
#  {'id': 'v2w34x',
#   'name': 'Victor Romano',
#   'email': 'victor.romano@italianflavor.com',
#   'is_blocked': False},
#  {'id': 'w3x45y',
#   'name': 'Wendy Zhang',
#   'email': 'wendy.zhang@cinematicarts.cn',
#   'is_blocked': False},
#  {'id': 'x4y56z',
#   'name': 'Xavier Lopez',
#   'email': 'xavier.lopez@spanishpassion.es',
#   'is_blocked': True},
#  {'id': 'y5z67a',
#   'name': 'Yuki Tanaka',
#   'email': 'yuki.tanaka@japaneseculture.jp',
#   'is_blocked': False},
#  {'id': 'z6a78b',
#   'name': 'Zara Williams',
#   'email': 'zara.williams@globalvoices.com',
#   'is_blocked': False},
#  {'id': 'a7b89c',
#   'name': 'Amelia Foster',
#   'email': 'amelia.foster@creativehearts.io',
#   'is_blocked': False},
#  {'id': 'b8c90d',
#   'name': 'Benjamin Hart',
#   'email': 'benjamin.hart@musicexpression.net',
#   'is_blocked': True},
#  {'id': 'c9d01e',
#   'name': 'Charlotte Lee',
#   'email': 'charlotte.lee@artisancraft.com',
#   'is_blocked': False},
#  {'id': 'd0e12f',
#   'name': 'Daniel Torres',
#   'email': 'daniel.torres@latinpulse.org',
#   'is_blocked': False},
#  {'id': 'e1f23g',
#   'name': 'Eleanor White',
#   'email': 'eleanor.white@classicalarts.net',
#   'is_blocked': True},
#  {'id': 'f2g34h',
#   'name': 'Felix Rodriguez',
#   'email': 'felix.rodriguez@culturalbridge.io',
#   'is_blocked': False},
#  {'id': 'g3h45i',
#   'name': 'Giselle Moreau',
#   'email': 'giselle.moreau@frenchculture.fr',
#   'is_blocked': False},
#  {'id': 'h4i56j',
#   'name': 'Harrison Blake',
#   'email': 'harrison.blake@theatricalarts.com',
#   'is_blocked': False},
#  {'id': 'i5j67k',
#   'name': 'Isabella Rossi',
#   'email': 'isabella.rossi@operahouse.it',
#   'is_blocked': True},
#  {'id': 'j6k78l',
#   'name': 'James Cohen',
#   'email': 'james.cohen@jazzlegend.net',
#   'is_blocked': False},
#  {'id': 'k7l89m',
#   'name': 'Jessica Park',
#   'email': 'jessica.park@koreanarts.kr',
#   'is_blocked': False},
#  {'id': 'l8m90n',
#   'name': 'Jordan Clarke',
#   'email': 'jordan.clarke@contempartist.io',
#   'is_blocked': False},
#  {'id': 'm9n01o',
#   'name': 'Katerina Volkov',
#   'email': 'katerina.volkov@russianculture.ru',
#   'is_blocked': True},
#  {'id': 'n0o12p',
#   'name': "Liam O'Connor",
#   'email': 'liam.oconnor@celticmusic.ie',
#   'is_blocked': False},
#  {'id': 'o1p23q',
#   'name': 'Lucia Bernardo',
#   'email': 'lucia.bernardo@portuguesearts.pt',
#   'is_blocked': False},
#  {'id': 'p2q34r',
#   'name': 'Marcus Thompson',
#   'email': 'marcus.thompson@worldmusic.com',
#   'is_blocked': False},
#  {'id': 'q3r45s',
#   'name': 'Natasha Volkova',
#   'email': 'natasha.volkova@balletcenter.net',
#   'is_blocked': True},
#  {'id': 'r4s56t',
#   'name': 'Owen McNamara',
#   'email': 'owen.mcnamara@irishculture.ie',
#   'is_blocked': False},
#  {'id': 's5t67u',
#   'name': 'Penelope Hart',
#   'email': 'penelope.hart@britisharts.co.uk',
#   'is_blocked': False},
#  {'id': 't6u78v',
#   'name': 'Quincy Adams',
#   'email': 'quincy.adams@contemporaryart.org',
#   'is_blocked': False},
#  {'id': 'u7v89w',
#   'name': 'Rebecca Stone',
#   'email': 'rebecca.stone@sculpturearts.net',
#   'is_blocked': True},
#  {'id': 'v8w90x',
#   'name': 'Sebastian Wright',
#   'email': 'sebastian.wright@modernarts.io',
#   'is_blocked': False},
#  {'id': 'w9x01y',
#   'name': 'Sophia Gallo',
#   'email': 'sophia.gallo@italianheritage.it',
#   'is_blocked': False}]

# %%
with get_session(engine) as session:
    db_users = []
    for user_info in cultpass_users:
        user = cultpass.User(
            user_id=user_info["id"],
            full_name=user_info["name"],
            email=user_info["email"],
            is_blocked=user_info["is_blocked"],
            created_at=datetime.now()
        )
        db_users.append(user)
    session.add_all(db_users)

# %% [markdown]
# **Subscription**

# %%
with get_session(engine) as session:
    subscriptions = []
    for user_info in cultpass_users:
        subscription = cultpass.Subscription(
            subscription_id=str(uuid.uuid4())[:6],
            user_id=user_info["id"],
            status=random.choice(["active", "cancelled"]),
            tier=random.choice(["basic", "premium"]),
            monthly_quota=random.randint(2,10),
            started_at=datetime.now()
        )
        subscriptions.append(subscription)

    session.add_all(subscriptions)

# %% [markdown]
# **Reservation**

# %%
# Applicable to `cultpass_users[0]` at the moment

with get_session(engine) as session:
    experience_ids = [
        exp.experience_id 
        for exp 
        in session.query(cultpass.Experience).all()
    ]

    reservation1 = cultpass.Reservation(
        reservation_id=str(uuid.uuid4())[:6],
        user_id=cultpass_users[0]["id"],
        experience_id=random.choice(experience_ids),
        status="reserved",
    )

    reservation2 = cultpass.Reservation(
        reservation_id=str(uuid.uuid4())[:6],
        user_id=cultpass_users[0]["id"],
        experience_id=random.choice(experience_ids),
        status="reserved",
    )

    session.add_all([reservation1, reservation2])

# %%
# TODO: Add more data
# Please notice that the reservations were set to first user only 
# If you want to simulate more users later, please create more reservations per user

with get_session(engine) as session:
    pass

# %% [markdown]
# # Tests

# %%
with get_session(engine) as session:
    users = session.query(cultpass.User).all()
    for user in users:
        print(user)
# Out:
# <User(user_id='a4ab87', email='alice.kingsley@wonderland.com', is_blocked=True)>
# <User(user_id='f556c0', email='bob.stone@granite.com', is_blocked=False)>
# <User(user_id='88382b', email='cathy.bloom@florals.org', is_blocked=False)>
# <User(user_id='888fb2', email='david.noir@shadowmail.com', is_blocked=True)>
# <User(user_id='f1f10d', email='eva.green@ecosoul.net', is_blocked=False)>
# <User(user_id='e6376d', email='frank.ocean@seawaves.io', is_blocked=False)>
# <User(user_id='g7h89i', email='grace.harper@melodyarts.com', is_blocked=False)>
# <User(user_id='h8i90j', email='henry.mitchell@buildtech.io', is_blocked=True)>
# <User(user_id='i9j01k', email='iris.chen@technovate.net', is_blocked=False)>
# <User(user_id='j0k12l', email='jack.wilson@sportsline.com', is_blocked=False)>
# <User(user_id='k1l23m', email='karen.santos@vibrantcultural.org', is_blocked=False)>
# <User(user_id='l2m34n', email='leo.martinez@latinarts.io', is_blocked=True)>
# <User(user_id='m3n45o', email='maya.patel@eastbound.net', is_blocked=False)>
# <User(user_id='n4o56p', email='nathan.brooks@riverdesign.com', is_blocked=False)>
# <User(user_id='o5p67q', email='olivia.schmidt@europeanculture.de', is_blocked=False)>
# <User(user_id='p6q78r', email='patrick.murphy@irishheritage.ie', is_blocked=True)>
# <User(user_id='q7r89s', email='quinn.davis@youngcreatives.io', is_blocked=False)>
# <User(user_id='r8s90t', email='rachel.adams@modernart.net', is_blocked=False)>
# <User(user_id='s9t01u', email='samuel.kim@asianfusion.org', is_blocked=False)>
# <User(user_id='t0u12v', email='tara.johnson@danceworld.io', is_blocked=True)>
# <User(user_id='u1v23w', email='uma.gupta@classicalmusic.net', is_blocked=False)>
# <User(user_id='v2w34x', email='victor.romano@italianflavor.com', is_blocked=False)>
# <User(user_id='w3x45y', email='wendy.zhang@cinematicarts.cn', is_blocked=False)>
# <User(user_id='x4y56z', email='xavier.lopez@spanishpassion.es', is_blocked=True)>
# <User(user_id='y5z67a', email='yuki.tanaka@japaneseculture.jp', is_blocked=False)>
# <User(user_id='z6a78b', email='zara.williams@globalvoices.com', is_blocked=False)>
# <User(user_id='a7b89c', email='amelia.foster@creativehearts.io', is_blocked=False)>
# <User(user_id='b8c90d', email='benjamin.hart@musicexpression.net', is_blocked=True)>
# <User(user_id='c9d01e', email='charlotte.lee@artisancraft.com', is_blocked=False)>
# <User(user_id='d0e12f', email='daniel.torres@latinpulse.org', is_blocked=False)>
# <User(user_id='e1f23g', email='eleanor.white@classicalarts.net', is_blocked=True)>
# <User(user_id='f2g34h', email='felix.rodriguez@culturalbridge.io', is_blocked=False)>
# <User(user_id='g3h45i', email='giselle.moreau@frenchculture.fr', is_blocked=False)>
# <User(user_id='h4i56j', email='harrison.blake@theatricalarts.com', is_blocked=False)>
# <User(user_id='i5j67k', email='isabella.rossi@operahouse.it', is_blocked=True)>
# <User(user_id='j6k78l', email='james.cohen@jazzlegend.net', is_blocked=False)>
# <User(user_id='k7l89m', email='jessica.park@koreanarts.kr', is_blocked=False)>
# <User(user_id='l8m90n', email='jordan.clarke@contempartist.io', is_blocked=False)>
# <User(user_id='m9n01o', email='katerina.volkov@russianculture.ru', is_blocked=True)>
# <User(user_id='n0o12p', email='liam.oconnor@celticmusic.ie', is_blocked=False)>
# <User(user_id='o1p23q', email='lucia.bernardo@portuguesearts.pt', is_blocked=False)>
# <User(user_id='p2q34r', email='marcus.thompson@worldmusic.com', is_blocked=False)>
# <User(user_id='q3r45s', email='natasha.volkova@balletcenter.net', is_blocked=True)>
# <User(user_id='r4s56t', email='owen.mcnamara@irishculture.ie', is_blocked=False)>
# <User(user_id='s5t67u', email='penelope.hart@britisharts.co.uk', is_blocked=False)>
# <User(user_id='t6u78v', email='quincy.adams@contemporaryart.org', is_blocked=False)>
# <User(user_id='u7v89w', email='rebecca.stone@sculpturearts.net', is_blocked=True)>
# <User(user_id='v8w90x', email='sebastian.wright@modernarts.io', is_blocked=False)>
# <User(user_id='w9x01y', email='sophia.gallo@italianheritage.it', is_blocked=False)>

# %%
with get_session(engine) as session:
    users = session.query(cultpass.User).all()
    for user in users:
        print(user.subscription)
# Out:
# <Subscription(subscription_id='6cb56c', user_id='a4ab87', status='active', tier='premium')>
# <Subscription(subscription_id='07676c', user_id='f556c0', status='cancelled', tier='premium')>
# <Subscription(subscription_id='9e81ef', user_id='88382b', status='cancelled', tier='premium')>
# <Subscription(subscription_id='92435b', user_id='888fb2', status='active', tier='basic')>
# <Subscription(subscription_id='5836de', user_id='f1f10d', status='cancelled', tier='premium')>
# <Subscription(subscription_id='a66cc8', user_id='e6376d', status='active', tier='premium')>
# <Subscription(subscription_id='6e9020', user_id='g7h89i', status='cancelled', tier='premium')>
# <Subscription(subscription_id='92bb26', user_id='h8i90j', status='active', tier='basic')>
# <Subscription(subscription_id='90559d', user_id='i9j01k', status='active', tier='basic')>
# <Subscription(subscription_id='468c22', user_id='j0k12l', status='cancelled', tier='premium')>
# <Subscription(subscription_id='6ffdf8', user_id='k1l23m', status='cancelled', tier='basic')>
# <Subscription(subscription_id='9ea834', user_id='l2m34n', status='active', tier='basic')>
# <Subscription(subscription_id='14bff6', user_id='m3n45o', status='active', tier='basic')>
# <Subscription(subscription_id='a279b9', user_id='n4o56p', status='active', tier='premium')>
# <Subscription(subscription_id='00bdfc', user_id='o5p67q', status='cancelled', tier='premium')>
# <Subscription(subscription_id='256562', user_id='p6q78r', status='cancelled', tier='basic')>
# <Subscription(subscription_id='338875', user_id='q7r89s', status='cancelled', tier='premium')>
# <Subscription(subscription_id='c7e15c', user_id='r8s90t', status='cancelled', tier='premium')>
# <Subscription(subscription_id='a30d3f', user_id='s9t01u', status='cancelled', tier='premium')>
# <Subscription(subscription_id='9e1ce4', user_id='t0u12v', status='active', tier='premium')>
# <Subscription(subscription_id='59987a', user_id='u1v23w', status='cancelled', tier='basic')>
# <Subscription(subscription_id='6a6e2d', user_id='v2w34x', status='cancelled', tier='basic')>
# <Subscription(subscription_id='107033', user_id='w3x45y', status='active', tier='basic')>
# <Subscription(subscription_id='8a8ae6', user_id='x4y56z', status='active', tier='premium')>
# <Subscription(subscription_id='559f69', user_id='y5z67a', status='active', tier='basic')>
# <Subscription(subscription_id='93b123', user_id='z6a78b', status='active', tier='basic')>
# <Subscription(subscription_id='9eb13a', user_id='a7b89c', status='cancelled', tier='basic')>
# <Subscription(subscription_id='958658', user_id='b8c90d', status='active', tier='basic')>
# <Subscription(subscription_id='a587e9', user_id='c9d01e', status='cancelled', tier='premium')>
# <Subscription(subscription_id='8926e8', user_id='d0e12f', status='cancelled', tier='premium')>
# <Subscription(subscription_id='8b918d', user_id='e1f23g', status='cancelled', tier='basic')>
# <Subscription(subscription_id='afc602', user_id='f2g34h', status='cancelled', tier='premium')>
# <Subscription(subscription_id='85fd5d', user_id='g3h45i', status='active', tier='basic')>
# <Subscription(subscription_id='e77990', user_id='h4i56j', status='active', tier='premium')>
# <Subscription(subscription_id='68d38b', user_id='i5j67k', status='cancelled', tier='premium')>
# <Subscription(subscription_id='2b7407', user_id='j6k78l', status='active', tier='basic')>
# <Subscription(subscription_id='6b1da8', user_id='k7l89m', status='cancelled', tier='premium')>
# <Subscription(subscription_id='de0b67', user_id='l8m90n', status='cancelled', tier='premium')>
# <Subscription(subscription_id='c50374', user_id='m9n01o', status='active', tier='basic')>
# <Subscription(subscription_id='0acbfb', user_id='n0o12p', status='active', tier='basic')>
# <Subscription(subscription_id='04d5a2', user_id='o1p23q', status='cancelled', tier='premium')>
# <Subscription(subscription_id='0c51e0', user_id='p2q34r', status='cancelled', tier='premium')>
# <Subscription(subscription_id='ee8e3d', user_id='q3r45s', status='active', tier='premium')>
# <Subscription(subscription_id='1ec3cf', user_id='r4s56t', status='active', tier='basic')>
# <Subscription(subscription_id='1a6235', user_id='s5t67u', status='cancelled', tier='basic')>
# <Subscription(subscription_id='fa83c7', user_id='t6u78v', status='active', tier='basic')>
# <Subscription(subscription_id='ca7068', user_id='u7v89w', status='cancelled', tier='premium')>
# <Subscription(subscription_id='864df0', user_id='v8w90x', status='cancelled', tier='basic')>
# <Subscription(subscription_id='5c6689', user_id='w9x01y', status='cancelled', tier='premium')>

# %%
with get_session(engine) as session:
    experiences = session.query(cultpass.Experience).all()
    for experience in experiences:
        print(experience)
# Out:
# <Experience(experience_id='b682a7', title='Carnival History Tour in Olinda', when='2026-03-12 00:09:24.083810')>
# <Experience(experience_id='95cf0f', title='Sunset Paddleboarding', when='2026-03-13 00:09:24.088648')>
# <Experience(experience_id='4a896e', title='Pelourinho Colonial Walk', when='2026-03-14 00:09:24.088680')>
# <Experience(experience_id='0fdc14', title='Samba Night at Lapa', when='2026-03-15 00:09:24.088698')>
# <Experience(experience_id='9fe334', title='Christ the Redeemer Experience', when='2026-03-16 00:09:24.088711')>
# <Experience(experience_id='e78ad4', title='Modern Art at MASP', when='2026-03-17 00:09:24.088725')>
# <Experience(experience_id='8b13e3', title='Ibirapuera Park Bike Ride', when='2026-03-18 00:09:24.088757')>
# <Experience(experience_id='e4e2de', title='Capoeira Workshop in Salvador', when='2026-03-19 00:09:24.088875')>
# <Experience(experience_id='44ec61', title='Ipanema Beach Sunset Yoga', when='2026-03-20 00:09:24.088899')>
# <Experience(experience_id='fcdb27', title='Street Art Tour in Vila Madalena', when='2026-03-21 00:09:24.088913')>
# <Experience(experience_id='f341f7', title='Forró Dance Classes', when='2026-03-22 00:09:24.088924')>
# <Experience(experience_id='d924d6', title='Bahia Culinary Experience', when='2026-03-23 00:09:24.088936')>
# <Experience(experience_id='ceef4e', title='Sugarloaf Mountain Hike', when='2026-03-24 00:09:24.088949')>
# <Experience(experience_id='817651', title='Indigenous Culture Workshop', when='2026-03-25 00:09:24.088961')>
# <Experience(experience_id='67b333', title='Botafogo Beach Volleyball', when='2026-03-26 00:09:24.088972')>
# <Experience(experience_id='7b80ff', title='Copacabana Music Night', when='2026-03-27 00:09:24.088983')>
# <Experience(experience_id='f28b7a', title='Iguazu Falls Eco-Tour', when='2026-03-28 00:09:24.088995')>
# <Experience(experience_id='c97f33', title='Carnival Costume Workshop', when='2026-03-29 00:09:24.089006')>
# <Experience(experience_id='88742a', title='Bossa Nova Jazz Night', when='2026-03-30 00:09:24.089017')>
# <Experience(experience_id='cc1696', title='Coffee Farm Tour', when='2026-03-31 00:09:24.089028')>
# <Experience(experience_id='32ad2b', title='Coral Reef Snorkeling', when='2026-04-01 00:09:24.089039')>
# <Experience(experience_id='06a575', title='Teatro Municipal Guided Tour', when='2026-04-02 00:09:24.089051')>
# <Experience(experience_id='931581', title='Favela Cultural Tour', when='2026-04-03 00:09:24.089061')>
# <Experience(experience_id='1885eb', title='Macramé and Textile Workshop', when='2026-04-04 00:09:24.089071')>
# <Experience(experience_id='becf74', title='Beach Soccer Clinic', when='2026-04-05 00:09:24.089081')>
# <Experience(experience_id='e2c314', title='Afro-Brazilian Music Percussion Class', when='2026-04-06 00:09:24.089169')>
# <Experience(experience_id='adb1b0', title='Amazon Jungle Expedition', when='2026-04-07 00:09:24.089231')>
# <Experience(experience_id='7f395d', title='Christ the Redeemer Sunrise Experience', when='2026-04-08 00:09:24.089257')>
# <Experience(experience_id='799d1e', title='Copacabana Palace Heritage Tour', when='2026-04-09 00:09:24.089271')>
# <Experience(experience_id='0dcb25', title='Traditional Moqueca Cooking Class', when='2026-04-10 00:09:24.089282')>
# <Experience(experience_id='eb6ba0', title='Corcovado Train Ride', when='2026-04-11 00:09:24.089293')>
# <Experience(experience_id='0f00ce', title='Brazilian Pottery Workshop', when='2026-04-12 00:09:24.089302')>
# <Experience(experience_id='eed56c', title='Lapa Street Art Mural Tour', when='2026-04-13 00:09:24.089312')>
# <Experience(experience_id='b7f77e', title='Manaus Opera House Tour', when='2026-04-14 00:09:24.089321')>
# <Experience(experience_id='e137fe', title='Tropical Fruit Market Experience', when='2026-04-15 00:09:24.089330')>
# <Experience(experience_id='1767f0', title='Samba School Rehearsal Visit', when='2026-04-16 00:09:24.089339')>
# <Experience(experience_id='c21132', title='Pantanal Wildlife Safari', when='2026-04-17 00:09:24.089349')>
# <Experience(experience_id='f70329', title='Bahian Women's Circle', when='2026-04-18 00:09:24.089358')>
# <Experience(experience_id='41418b', title='Sugar Mill Historical Tour', when='2026-04-19 00:09:24.089367')>
# <Experience(experience_id='287c1f', title='Samba Costuming and Styling', when='2026-04-20 00:09:24.089376')>
# <Experience(experience_id='96048c', title='Tropical Plant Botanical Walk', when='2026-04-21 00:09:24.089385')>
# <Experience(experience_id='bf2414', title='Candombe Drums Workshop', when='2026-04-22 00:09:24.089395')>
# <Experience(experience_id='dd83d9', title='Rio Food Tour', when='2026-04-23 00:09:24.089404')>
# <Experience(experience_id='4cb065', title='Pampas Horseback Riding', when='2026-04-24 00:09:24.089414')>
# <Experience(experience_id='494e17', title='Sacred Waterfall Meditation', when='2026-04-25 00:09:24.089423')>
# <Experience(experience_id='e93f69', title='Brazilian Martial Arts Festival', when='2026-04-26 00:09:24.089432')>
# <Experience(experience_id='4112c4', title='Tidal Wave Surfing Experience', when='2026-04-27 00:09:24.089441')>
# <Experience(experience_id='8643b1', title='Candomblé Spiritual Ceremony', when='2026-04-28 00:09:24.089451')>
# <Experience(experience_id='90e85d', title='Brazilian Literature Salon', when='2026-04-29 00:09:24.089459')>
# <Experience(experience_id='27f2e3', title='Sustainable Rainforest Project', when='2026-04-30 00:09:24.089469')>
